# %% [markdown]
# #HealPix image transforms for WWT
# This notebook contains the scripts for reprojecting and colorizing CMB maps from Zhen Hou.
#
# Jeffrey SubbaRao, Mark SubbaRao
#
# KICP WWT workshop, July 28th 2015

# %%
import healpy
import numpy
import matplotlib
# %matplotlib inline

# %% [markdown]
# ###Loop through and process all the .fits files in the same directory as the nootbook

# %%
files  = !ls *.fits

# %%
for f in files:
    hmap = healpy.fitsfunc.read_map(f)
    m = healpy.cartview(hmap,title = "", return_projected_map=True,notext=True,cbar=False,xsize=6000, margins= None, cmap="RdBu")
    matplotlib.pyplot.imsave(f[:-5]+'.png', m, cmap="RdBu")
# Out:
# NSIDE = 1024
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 1024
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 1024
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %% [markdown]
# ###Code for porcessing just one map
# ####Load Map

# %%
hmap = healpy.fitsfunc.read_map('map_lmax2500_nside1024_interp0.3_method1_1_sim0_phi_map.fits')
m = healpy.cartview(hmap,title = "", return_projected_map=True,notext=True,cbar=False,xsize=6000, margins= None, cmap="RdBu")
# Out:
# NSIDE = 1024
# ORDERING = RING in fits file

# %% [markdown]
# ####Map histogram

# %%
matplotlib.pyplot.hist(numpy.reshape(m,-1),100)
# Out:
# (array([    669.,    2340.,    5594.,   12933.,   25569.,   34199.,
#           41140.,   39540.,   43748.,   46016.,   49382.,   57849.,
#           64441.,   69589.,   78335.,   89226.,  112691.,  118111.,
#          126875.,  136796.,  140579.,  143437.,  152010.,  160322.,
#          193476.,  220599.,  239362.,  239929.,  235636.,  267249.,
#          265877.,  263643.,  271456.,  283478.,  285813.,  270961.,
#          266436.,  268626.,  253328.,  253316.,  271888.,  286248.,
#          302214.,  363925.,  370526.,  345137.,  345750.,  352103.,
#          339950.,  343121.,  390337.,  464885.,  450054.,  477712.,
#          508758.,  433479.,  364205.,  351394.,  321821.,  332181.,
#          322955.,  331797.,  302323.,  265073.,  255098.,  251186.,
#          268100.,  253242.,  233702.,  223377.,  216024.,  209708.,
#          197441.,  186018.,  157058.,  137728.,  114965.,   93840.,
#           86796.,   71934.,   64392.,   53891.,   48152.,   37005.,
# ...

# %% [markdown]
# ####Save Map

# %%
 matplotlib.pyplot.imsave('map_lmax2500_nside1024_interp0.3_method1_1_sim0_phi_map_cart.png', m, cmap="RdBu")
