# %% [markdown]
# # Processing the LIGO event skymaps in for Uniview
#
# We'll get the skylocation probibility maps from here: https://losc.ligo.org/events/GW150914/
# There are four different methods to choose from. They are HEALPIX-FITS files
#
# The file that is saved from this process requires a vertical flip (fr some reason I doon't understand, what is saved is flipped from the correct way it is plotted below.

# %%
import healpy
import numpy
import matplotlib
# %matplotlib inline

# %%
from astropy.time import Time

# %%
gwmap = healpy.fitsfunc.read_map('LALInference_skymap.fits')
# Out:
# NSIDE = 512
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING

# %%
m = healpy.cartview(gwmap,title = "", return_projected_map=True,notext=True,cbar=False,xsize=2048, margins= None, cmap="gray")

# %%
m1_gal = healpy.cartview(gwmap,title = "", coord=['E','G'],return_projected_map=True,notext=True,cbar=False,xsize=2048, margins= None, cmap="gray")

# %%
matplotlib.pyplot.imsave('LIGO_GW150914_LAL_gr.png', m, cmap="gray")

# %%
matplotlib.pyplot.imsave('LIGO_GW150914_LAL_gal_gr.png', m1_gal, cmap="gray")

# %%
t1 = Time('2015-09-14T09:50:45', format='isot', scale='utc')
t1.mjd
# Out:
# 57279.41024305556

# %% [markdown]
# ## Skymap for GW151226
#
# We will use the LALinterference mao from here: https://losc.ligo.org/events/GW151226/

# %%
gwmap2 = healpy.fitsfunc.read_map('LALInference_skymap_gw151226.fits')
# Out:
# NSIDE = 512
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING

# %%
m2 = healpy.cartview(gwmap2,title = "", return_projected_map=True,notext=True,cbar=False,xsize=2048, margins= None, cmap="gray")

# %%
m2_gal = healpy.cartview(gwmap2,coord=['E','G'],title = "", return_projected_map=True,notext=True,cbar=False,xsize=2048, margins= None, cmap="gray")

# %%
matplotlib.pyplot.imsave('LIGO_GW151226_LAL_gr.png', m2, cmap="gray")

# %%
matplotlib.pyplot.imsave('LIGO_GW151226_LAL_gal_gr.png', m2_gal, cmap="gray")

# %%
t2 = Time('2015-12-26T03:38:53.65', format='isot', scale='utc')
t2.mjd
# Out:
# 57382.15200983796

# %% [markdown]
# ## Skymap for LVT151012
#
# We will use the LALinterference mao from here: https://losc.ligo.org/events/LVT151012/

# %%
gwmap3 = healpy.fitsfunc.read_map('LALInference_skymap_lvt151012.fits')
# Out:
# NSIDE = 512
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING

# %%
m3 = healpy.cartview(gwmap3,title = "", return_projected_map=True,notext=True,cbar=False,xsize=2048, margins= None, cmap="gray")

# %%
m3_gal = healpy.cartview(gwmap3,coord=['E','G'],title = "", return_projected_map=True,notext=True,cbar=False,xsize=2048, margins= None, cmap="gray")

# %%
matplotlib.pyplot.imsave('LIGO_lvt151012_LAL_gr.png', m3, cmap="gray")

# %%
matplotlib.pyplot.imsave('LIGO_lvt151012_LAL_gal_gr.png', m3_gal, cmap="gray")

# %%
t3 = Time('2015-10-12T09:54:43.44', format='isot', scale='utc')
t3.mjd
# Out:
# 57307.41300277778
